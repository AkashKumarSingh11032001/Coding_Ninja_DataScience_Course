# %% [markdown]
# # 24. Web Scraping - Selenium - 1

# %%
from selenium import webdriver

# %%
driver = webdriver.Edge(executable_path = 'E:/Software Programs Files/MicrosoftEdgeDrivers/edgedriver_win64/edge.exe')
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="66c168385a007323e1fe63a8e925487e")>

# %%
# oping particular website
driver.get('https://codingninjas.in/')

# %%
# pressing back button 
driver.back()

# %%
# pressing forward button
driver.forward()

# %%
# getting main title o website
driver.title()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-ea90064e5a94> in <module>
#       1 # getting main title o website
# ----> 2 driver.title()
#
# TypeError: 'str' object is not callable

# %%
# taking screenshot o0f webpage
driver.save_screenshot('ss1.png')

# %%
# getting all html content from webpage
driver.page_source
# Out:
# '<html lang="en" style="--batchMonthBG:#FFEBC2; --batchCardBC:#FFEBC2; --batchMonthTC:#AC933C;"><head>\n    <meta charset="utf-8">\n    <title>Coding Ninjas – Learn coding online at India’s best coding institute</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Coding Ninjas – Learn coding online at India’s best coding institute">\n    <meta property="og:title" content="Coding Ninjas – Learn coding online at India’s best coding institute">\n    <meta name="description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:image" content="https://files.codingninjas.in/000000000000
# ...

# %%
# find ele by link text
reg_btn = driver.find_element_by_link_text('Register')
reg_btn.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-35-bebe2e55e724> in <module>
#       1 # find ele by link text
# ----> 2 reg_btn = driver.find_element_by_link_text('Register')
#       3 reg_btn.click()
#
# E:\Software Programs Files\Anaconda-Data\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_link_text(self, link_text)
#     426             element = driver.find_element_by_link_text('Sign In')
#     427         """
# --> 428         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     429
#     430     def find_elements_by_link_text(self, text):
#
# E:\Software Programs Files\Anaconda-Data\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# ...

# %%
reg_btn = driver.find_element_by_partial_link_text('Reg')
reg_btn.click()

# %%
# maximize_window()
driver.maximize_window()

# %%
# refresh()
driver.refresh()

# %%
# close/quit

driver.close() #only current window will be closed
driver.quit # close all windows
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-20-4adad4e8e5c6> in <module>
#       1 # close/quit
#       2
# ----> 3 driver.close() #only current window will be closed
#       4 driver.quit # close all windows
#
# E:\Software Programs Files\Anaconda-Data\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# E:\Software Programs Files\Anaconda-Data\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
# ...

# %%
# try this
driver.get(driver.current_url()) # == it is equal to driver.refresh()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-6c914cbc9602> in <module>
#       1 # try this
# ----> 2 driver.get(driver.current_url()) # == it is equal to driver.refresh()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ### Locate element

# %%
from selenium import webdriver
driver = webdriver.Edge(executable_path = 'E:/Software Programs Files/MicrosoftEdgeDrivers/edgedriver_win64/edge.exe')
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="fa98ecb5051e68ff92c1967ab050ff7e")>

# %%
driver.get('http://books.toscrape.com/')

# %%
#moving to category "Music" -> return firsst occurenec
c1 = driver.find_element_by_link_text("Music")
c1.click()

# %%
b1 = driver.find_element_by_partial_link_text("Kill") #-> return firsst occurenec
b1.click()

# %%
driver.back()

# %%
i1 = driver.find_element_by_class_name('image_container')
i1.click() # first book only

# %%
k1 = driver.find_elements_by_class_name('image_container')
len(k1) # all book
# Out:
# 20

# %%
driver.find_element_by_tag_name('img')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="93ef45001ffba8f8e15a8d6b8caa024f", element="a7f8302f-8481-4497-a54c-9ebab5450078")>

# %%
a = driver.find_element_by_tag_name('img')
print(type(a))
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>

# %%
k1 = driver.find_element_by_class_name('price_color')
k1.click()
